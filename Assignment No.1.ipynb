# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
full_name = "Muhammad Talha Uddin"
print(full_name.upper())
# Out:
# MUHAMMAD TALHA UDDIN

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
fav_fruit = input("apka favorite fruit kaunsa hai? ")
length = len(fav_fruit)
print(f"Aapke favorite fruit mein {length} characters hain.")
# Out:
# apka favorite fruit kaunsa hai?  Mango
# Aapke favorite fruit mein 5 characters hain.

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
sentence = "Python is fun"
new_sentence = sentence.replace("fun", "awesome")
print(new_sentence)
# Out:
# Python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
text = "Hello World"
index_position = text.find("World")
print(f"'World' index number {index_position} se start hota hai.")
# Out:
# 'World' index number 6 se start hota hai.

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein

# %%
user_email = input("apna email address enter karein: ")
clean_email = user_email.lower()
print(f"Aapka processed email hai: {clean_email}")
# Out:
# apna email address enter karein:  talhafarooqui479@gmail.com
# Aapka processed email hai: talhafarooqui479@gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
sentence = "  Python Programming  "
cleaned_sentence = sentence.strip()
print(f"Original: '{sentence}'")
print(f"Cleaned: '{cleaned_sentence}'")
# Out:
# Original: '  Python Programming  '
# Cleaned: 'Python Programming'

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
sentence = "Welcome to coding"
count_o = sentence.count('o')
print(f"Letter 'o' is sentence mein {count_o} baar aaya hai.")
# Out:
# Letter 'o' is sentence mein 3 baar aaya hai.

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
age = input("Apni age enter karein: ")
age = int(age)
print("Aap ki age hai:", age)
# Out:
# Apni age enter karein:  23
# Aap ki age hai: 23

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
float = 15.99
converted_price = int(float)
print(converted_price)
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
num1_str = input("Pehla number enter karein: ")
num2_str = input("Doosra number enter karein: ")

num1 = int(num1_str)
num2 = int(num2_str)

sum_result = num1 + num2
print("Dono numbers ka sum hai:", sum_result)
# Out:
# Pehla number enter karein:  55
# Doosra number enter karein:  44
# Dono numbers ka sum hai: 99

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
number = 100
converted_string = str(number)
print(converted_string)
print(type(converted_string))
# Out:
# 100
# <class 'str'>

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
price = input("Price enter karein: ")
price = int(float(price))
print("Integer value:", price)
# Out:
# Price enter karein:  125.5
# Integer value: 125

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
str1 = "10"
str2 = "20"
result = int(str1) + int(str2)
print(result)
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
num = '50.5'
result = float(num) + 10
print("Result:", result)
# Out:
# Result: 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
name = input("Apna naam enter karein: ")
city = input("Apna shehar enter karein: ")
print(f"Hello {name}, welcome to {city}")
# Out:
# Apna naam enter karein:  Muhammad Talha Uddin
# Apna shehar enter karein:  Karachi
# Hello Muhammad Talha Uddin, welcome to Karachi

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
num1 = float(input("Pehla number enter karein: "))
num2 = float(input("Doosra number enter karein: "))
product = num1 * num2
print("Product:", product)
# Out:
# Pehla number enter karein:  89
# Doosra number enter karein:  22
# Product: 1958.0

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
color = input("Apna favorite color enter karein: ")
print(f"I also like {color}")
# Out:
# Apna favorite color enter karein:  yellow
# I also like yellow

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
current_year = 2026
birth_year = int(input("Apna birth year enter karein: "))
age = current_year - birth_year
print("Aap ki current age hai:", age)
# Out:
# Apna birth year enter karein:  2002
# Aap ki current age hai: 24

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
word = input("Ek word enter karein: ")
print((word + " ") * 5)
# Out:
# Ek word enter karein:  apple
# apple apple apple apple apple

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
mobile_number = input("Apna mobile number enter karein: ")
print("Aap ne ye mobile number type kiya hai:", mobile_number)
# Out:
# Apna mobile number enter karein:  03102590166
# Aap ne ye mobile number type kiya hai: 03102590166

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
a = 10
b = 3
remainder = a % b
print("Remainder:", remainder)
# Out:
# Remainder: 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
num = 15
result = (num > 10) and (num < 20)
print(result)
# Out:
# True

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
num = float(input("Ek number enter karein: "))
if num > 100:
    print("Yes, number 100 se bada hai.")
else:
    print("No, number 100 se bada nahi hai.")
# Out:
# Ek number enter karein:  14
# No, number 100 se bada nahi hai.

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
result = 2 ** 5
print(result)
# Out:
# 32

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
a = 50
b = 100
result = (a == b)
print(result)
# Out:
# False

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
a = True
b = False
result = a or b
print(result)
# Out:
# True

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
num = float(input("Ek number enter karein: "))
if num > 0:
    print("Number Positive hai.")
elif num < 0:
    print("Number Negative hai.")
else:
    print("Number zero hai.")
# Out:
# Ek number enter karein:  55
# Number Positive hai.

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
age = int(input("Apni age enter karein: "))
if age > 18:
    print("Eligible for Vote")
else:
    print("Not Eligible for Vote")
# Out:
# Apni age enter karein:  24
# Eligible for Vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
num = int(input("Ek number enter karein: "))
if num % 2 == 0:
    print("Even number hai.")
else:
    print("Odd number hai.")
# Out:
# Ek number enter karein:  32
# Even number hai.

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
num1 = float(input("Pehla number enter karein: "))
num2 = float(input("Doosra number enter karein: "))
if num1 > num2:
    print("Bada number hai:", num1)
elif num2 > num1:
    print("Bada number hai:", num2)
else:
    print("Dono numbers barabar hain.")
# Out:
# Pehla number enter karein:  22
# Doosra number enter karein:  44
# Bada number hai: 44.0

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
marks = float(input("Apne marks enter karein: "))
if marks > 33:
    print("Pass")
else:
    print("Fail")
# Out:
# Apne marks enter karein:  78
# Pass

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
text = input("Kuch text enter karein: ")
if text != "":
    print("String empty nahi hai.")
else:
    print("String empty hai.")
# Out:
# Kuch text enter karein:  Talha
# String empty nahi hai.

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
password = input("Password enter karein: ")
if password == "python123":
    print("Access Granted")
else:
    print("Wrong Password")
# Out:
# Password enter karein:  saylani123
# Wrong Password

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
# User se number lena
num = float(input("Ek number enter karein: "))

# Check karna zero hai ya nahi
if num == 0:
    print("Number zero hai.")
else:
    print("Number zero nahi hai.")
# Out:
# Ek number enter karein:  12
# Number zero nahi hai.

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
marks = float(input("Apne marks enter karein: "))

if marks >= 90:
    print("Grade: A")
elif marks >= 80:
    print("Grade: B")
elif marks >= 70:
    print("Grade: C")
else:
    print("Grade: D")
# Out:
# Apne marks enter karein:  52
# Grade: D

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
# User se temperature lena
temp = float(input("Temperature enter karein: "))

# Condition check karna
if temp > 30:
    print("Hot")
elif temp >= 15:
    print("Warm")
else:
    print("Cold")
# Out:
# Temperature enter karein:  32
# Hot

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
num = int(input("Ek number enter karein: "))

if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz (3 aur 5 dono se divisible hai)")
elif num % 3 == 0:
    print("Fizz (3 se divisible hai)")
elif num % 5 == 0:
    print("Buzz (5 se divisible hai)")
else:
    print("Na 3 se divisible hai na 5 se")
# Out:
# Ek number enter karein:  65
# Buzz (5 se divisible hai)

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
char = input("Ek character enter karein: ").lower()
vowels = "aeiou"

if char in vowels:
    print("Vowel hai")
else:
    print("Consonant hai")
# Out:
# Ek character enter karein:  Pakistan
# Consonant hai

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
bill = float(input("Apni shopping bill enter karein: "))

if bill > 5000:
    discount = bill * 0.20
    final_amount = bill - discount
    print("20% Discount applied")
    print("Final Bill:", final_amount)

elif bill >= 2000:
    discount = bill * 0.10
    final_amount = bill - discount
    print("10% Discount applied")
    print("Final Bill:", final_amount)

else:
    print("No discount applied")
    print("Final Bill:", bill)
# Out:
# Apni shopping bill enter karein:  10500
# 20% Discount applied
# Final Bill: 8400.0

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
age = int(input("Apni age enter karein: "))

if age >= 0 and age <= 12:
    print("Child")
elif age >= 13 and age <= 19:
    print("Teenager")
elif age >= 20 and age <= 59:
    print("Adult")
else:
    print("Senior Citizen")
# Out:
# Apni age enter karein:  24
# Adult

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
year = int(input("Year enter karein: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year hai")
else:
    print("Leap Year nahi hai")
# Out:
# Year enter karein:  2026
# Leap Year nahi hai

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
day_num = int(input("Week number enter karein (1-7): "))

if day_num == 1:
    print("Monday")
elif day_num == 2:
    print("Tuesday")
elif day_num == 3:
    print("Wednesday")
elif day_num == 4:
    print("Thursday")
elif day_num == 5:
    print("Friday")
elif day_num == 6:
    print("Saturday")
elif day_num == 7:
    print("Sunday")
else:
    print("Invalid input! Sirf 1 se 7 tak number enter karein.")
# Out:
# Week number enter karein (1-7):  5
# Friday

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
num1 = float(input("Pehla number enter karein: "))
num2 = float(input("Doosra number enter karein: "))

op = input("Operation enter karein (+, -, *, /): ")

if op == "+":
    print("Result:", num1 + num2)

elif op == "-":
    print("Result:", num1 - num2)

elif op == "*":
    print("Result:", num1 * num2)

elif op == "/":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error: Division by zero not allowed")

else:
    print("Invalid operator")
# Out:
# Pehla number enter karein:  24
# Doosra number enter karein:  55
# Operation enter karein (+, -, *, /):  +
# Result: 79.0

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
weight = float(input("Apna weight (kg) enter karein: "))
height = float(input("Apni height (meters) enter karein: "))

bmi = weight / (height ** 2)

if bmi < 18.5:
    print("Underweight")
elif bmi < 25:
    print("Normal weight")
else:
    print("Overweight")

print("BMI:", bmi)
# Out:
# Apna weight (kg) enter karein:  60
# Apni height (meters) enter karein:  1.8
# Normal weight
# BMI: 18.51851851851852

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
correct_pin = "1234"
balance = 10000

pin = input("Apna PIN enter karein: ")

if pin == correct_pin:
    
    amount = float(input("Withdraw amount enter karein: "))
    
    if amount <= balance:
        print("Withdrawal Success")
        balance -= amount
        print("Remaining Balance:", balance)
    else:
        print("Insufficient Balance")
        
else:
    print("Wrong PIN")
# Out:
# Apna PIN enter karein:  1234
# Withdraw amount enter karein:  5000
# Withdrawal Success
# Remaining Balance: 5000.0

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
correct_username = "admin"
correct_password = "python123"

username = input("Username enter karein: ")

if username == correct_username:
    
    password = input("Password enter karein: ")
    
    if password == correct_password:
        print("Login Successful")
    else:
        print("Wrong Password")
        
else:
    print("Invalid Username")
# Out:
# Username enter karein:  admin
# Password enter karein:  python123
# Login Successful

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
num1 = float(input("Pehla number enter karein: "))
num2 = float(input("Doosra number enter karein: "))
num3 = float(input("Teesra number enter karein: "))

if num1 > num2:
    if num1 > num3:
        print("Sabse bada number hai:", num1)
    else:
        print("Sabse bada number hai:", num3)
else:
    if num2 > num3:
        print("Sabse bada number hai:", num2)
    else:
        print("Sabse bada number hai:", num3)
# Out:
# Pehla number enter karein:  5
# Doosra number enter karein:  66
# Teesra number enter karein:  89
# Sabse bada number hai: 89.0

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
age = int(input("Apni age enter karein: "))

if age >= 18:
    
    id_card = input("Kya aap ke paas ID hai? (yes/no): ").lower()
    
    if id_card == "yes":
        print("Ticket Issued")
    else:
        print("ID required, Ticket not issued")
        
else:
    print("You are under 18, Ticket not allowed")
# Out:
# Apni age enter karein:  24
# Kya aap ke paas ID hai? (yes/no):  yes
# Ticket Issued

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
marks = float(input("Apne marks enter karein: "))

if marks >= 80:
    
    interview = input("Kya interview clear hai? (yes/no): ").lower()
    
    if interview == "yes":
        print("Admission Done")
    else:
        print("Interview clear nahi hua, Admission not granted")
        
else:
    print("Marks kam hain, Admission not granted")
# Out:
# Apne marks enter karein:  76
# Marks kam hain, Admission not granted

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
num = float(input("Ek number enter karein: "))

if num > 0:
    
    if num > 100:
        print("Number Positive hai aur 100 se bada hai")
    else:
        print("Number Positive hai aur 100 se chota ya equal hai")

else:
    print("Number Positive nahi hai")
# Out:
# Ek number enter karein:  50
# Number Positive hai aur 100 se chota ya equal hai

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
category = input("Veg ya Non-Veg select karein: ").lower()

if category == "veg":
    
    veg_item = input("Paneer ya Dal select karein: ").lower()
    
    if veg_item == "paneer":
        print("Aapka order: Paneer")
    elif veg_item == "dal":
        print("Aapka order: Dal")
    else:
        print("Invalid veg item selected")

elif category == "non-veg":
    
    nonveg_item = input("Chicken ya Mutton select karein: ").lower()
    
    if nonveg_item == "chicken":
        print("Aapka order: Chicken")
    elif nonveg_item == "mutton":
        print("Aapka order: Mutton")
    else:
        print("Invalid non-veg item selected")

else:
    print("Invalid category selected (sirf Veg ya Non-Veg)")
# Out:
# Veg ya Non-Veg select karein:  veg
# Paneer ya Dal select karein:  dal
# Aapka order: Dal

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
num = abs(int(input("Ek number enter karein: ")))

if num >= 0 and num <= 9:
    print("Single digit number hai")
elif num <= 99:
    print("Double digit number hai")
elif num <= 999:
    print("Triple digit number hai")
else:
    print("3 se zyada digits ka number hai")
# Out:
# Ek number enter karein:  20
# Double digit number hai

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
salary = float(input("Apni salary enter karein: "))
years = int(input("Service years enter karein: "))

if years > 5:
    bonus = salary * 0.05
    final_salary = salary + bonus
    print("5% Bonus applied")
    print("Final Salary:", final_salary)
else:
    print("No bonus applied")
    print("Salary:", salary)
# Out:
# Apni salary enter karein:  60000
# Service years enter karein:  4
# No bonus applied
# Salary: 60000.0

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
a = float(input("Pehli side enter karein: "))
b = float(input("Doosri side enter karein: "))
c = float(input("Teesri side enter karein: "))

if a == b and b == c:
    print("Equilateral Triangle")
elif a == b or b == c or a == c:
    print("Isosceles Triangle")
else:
    print("Scalene Triangle")
# Out:
# Pehli side enter karein:  20
# Doosri side enter karein:  20
# Teesri side enter karein:  20
# Equilateral Triangle

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
month = input("Month ka naam enter karein: ").lower()

if month == "january" or month == "march" or month == "may" or month == "july" or month == "august" or month == "october" or month == "december":
    print("31 days hote hain")

elif month == "april" or month == "june" or month == "september" or month == "november":
    print("30 days hote hain")

elif month == "february":
    print("28 ya 29 days hote hain (Leap year par depend karta hai)")

else:
    print("Invalid month name")
# Out:
# Month ka naam enter karein:  june
# 30 days hote hain

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
# User se number lena
num = int(input("Ek number enter karein: "))

# Even check
if num % 2 == 0:
    
    # Nested condition
    if num > 50:
        print("Even hai aur 50 se bada hai")
    else:
        print("Even hai aur 50 se chota ya equal hai")
        
else:
    print("Number Even nahi hai")
# Out:
# Ek number enter karein:  44
# Even hai aur 50 se chota ya equal hai

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
maths = float(input("Maths ke marks enter karein: "))
science = float(input("Science ke marks enter karein: "))

# Result check karna (Nested if-else)
if maths >= 40:
    
    if science >= 40:
        print("Pass")
    else:
        print("Fail - Science weak hai")

else:
    
    if science >= 40:
        print("Fail - Maths weak hai")
    else:
        print("Fail - Maths aur Science dono weak hain")
# Out:
# Maths ke marks enter karein:  65
# Science ke marks enter karein:  73
# Pass

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
units = float(input("Units enter karein: "))
bill = 0
if units <= 100:
    bill = 0

elif units <= 200:
    bill = (units - 100) * 5

else:
    bill = (100 * 5) + (units - 200) * 10

print("Total Bill:", bill)
# Out:
# Units enter karein:  155
# Total Bill: 275.0

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
score = int(input("Apna score enter karein: "))

if score <= 50:
    print("Beginner Level")

elif score <= 100:
    print("Intermediate Level")
    
    boss = input("Kya aapne boss level complete kiya hai? (yes/no): ").lower()
    
    if boss == "yes":
        print("Boss Level Completed 🎉")
    else:
        print("Boss Level Pending")

else:
    print("Invalid score range")
# Out:
# Apna score enter karein:  56
# Intermediate Level
# Kya aapne boss level complete kiya hai? (yes/no):  yes
# Boss Level Completed 🎉

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
correct_username = "admin"
correct_password = "python123"
correct_answer = "karachi"

username = input("Username enter karein: ")

if username == correct_username:
    
    password = input("Password enter karein: ")
    
    if password == correct_password:
        
        print("Security Question: Aap ka shehar ka naam kya hai?")
        answer = input("Answer enter karein: ").lower()
        
        if answer == correct_answer:
            print("Access Granted")
        else:
            print("Wrong Security Answer")
            
    else:
        print("Wrong Password")
        
else:
    print("Invalid Username")
# Out:
# Username enter karein:  admin
# Password enter karein:  python123
# Security Question: Aap ka shehar ka naam kya hai?
# Answer enter karein:  Karachi
# Access Granted
